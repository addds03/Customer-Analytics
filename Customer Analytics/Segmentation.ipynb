# %% [markdown]
# ## Library Imports

# %%
import numpy as np
import pandas as pd
import scipy
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.preprocessing import RobustScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
df_seg = pd.read_csv('segmentation data.csv', index_col=0)

# %% [markdown]
# ## Summary

# %%
df_seg.head()
# Out:
#            Sex  Marital status  Age  Education  Income  Occupation  \
# ID
# 100000001    0               0   67          2  124670           1
# 100000002    1               1   22          1  150773           1
# 100000003    0               0   49          1   89210           0
# 100000004    0               0   45          1  171565           1
# 100000005    0               0   53          1  149031           1
#
#            Settlement size
# ID
# 100000001                2
# 100000002                2
# 100000003                0
# 100000004                1
# 100000005                1

# %%
df_seg.describe()
# Out:
#                Sex  Marital status          Age   Education         Income  \
# count  2000.000000     2000.000000  2000.000000  2000.00000    2000.000000
# mean      0.457000        0.496500    35.909000     1.03800  120954.419000
# std       0.498272        0.500113    11.719402     0.59978   38108.824679
# min       0.000000        0.000000    18.000000     0.00000   35832.000000
# 25%       0.000000        0.000000    27.000000     1.00000   97663.250000
# 50%       0.000000        0.000000    33.000000     1.00000  115548.500000
# 75%       1.000000        1.000000    42.000000     1.00000  138072.250000
# max       1.000000        1.000000    76.000000     3.00000  309364.000000
#
#         Occupation  Settlement size
# count  2000.000000      2000.000000
# mean      0.810500         0.739000
# std       0.638587         0.812533
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       1.000000         1.000000
# 75%       1.000000         1.000000
# max       2.000000         2.000000

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(12,9))

s = sns.heatmap(df_seg.corr(),
            annot=True,
            vmin = -1,
            vmax = 1,
            cmap = 'RdBu')
s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize=12)
s.set_xticklabels(s.get_xticklabels(), rotation = 45, fontsize=12)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(12,9))
sns.set_style('whitegrid')
sns.scatterplot(x = df_seg['Age'],y = df_seg['Income'])
plt.title('Age vs Income distribution')
plt.show()

# %% [markdown]
# *It would be a better idea to club numerical variables and plot summary of the data.*

# %% [markdown]
# ## Standardization

# %% [markdown]
# *Used standardization to scale the data to a similar min-max value*

# %%
scale = RobustScaler()
df_seg_prep = scale.fit_transform(df_seg)

# %% [markdown]
# ## Clustering Methods
# ---
#    ### Hierarchical

# %%
 hier_clust = linkage(df_seg_prep, method='ward')

# %%
plt.figure(figsize=(12,9))
plt.title('Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')

dendrogram(hier_clust,
           truncate_mode='level',p=5,
          show_leaf_counts=False,
          no_labels=True)
plt.show()

# %% [markdown]
# 1. *Hierarchical clustering is slow and may take hours if we have a large dataset.*
# 2. *It almost always generates/predicts the number of clusters, we can use that number on flat clustering methods for big data.*
# ---
# ### K-means

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=10)
    kmeans.fit(df_seg_prep)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(12,9))
plt.title('K-means Clustering')
plt.xlabel('Number of Clusters')
plt.ylabel('Within Cluster Sum Squared')
plt.plot(range(1,11), wcss, marker = 'o', linestyle = '--')
plt.show()

# %% [markdown]
# *From the plot above,
# To select the number of clusters for K-means clustering, we select the elbow of the graph. i.e Check where our curve smooths after a steep drop.*
#
# ***Based on our results from K-means and Hierarchical clustering, we can either select 3 or 4 clusters***

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=10)
kmeans.fit(df_seg_prep)
# Out:
# KMeans(n_clusters=4, random_state=10)

# %% [markdown]
# ## Results

# %%
seg_res = df_seg.copy()
seg_res['Segment'] = kmeans.labels_

# %%
df_analysis = seg_res.groupby(['Segment']).mean()

# %% [markdown]
# ***Segments***
#
# 0. *Fewer Opportunities*
# 1. *Standard*
# 2. *Career Focused*
# 3. *Well off*

# %%
df_analysis['n_obs'] = seg_res[['Segment','Sex']].groupby(['Segment']).count()
df_analysis['prop'] = df_analysis['n_obs'] / df_analysis['n_obs'].sum()

# %%
df_analysis.rename({0:'Fewer Opportunities',1:'Standard',
                    2:'Career Focused',3:'Well-off'})
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment
# Fewer Opportunities  0.599034        0.521739  30.932367   0.844203
# Standard             0.331395        0.470930  31.665698   0.824128
# Career Focused       0.237069        0.375000  45.827586   1.379310
# Well-off             0.535714        0.595238  54.714286   1.944444
#
#                             Income  Occupation  Settlement size  n_obs   prop
# Segment
# Fewer Opportunities   96745.560386    0.397343         0.007246    828  0.414
# Standard             124660.145349    1.103198         1.434593    688  0.344
# Career Focused       193374.818966    1.668103         1.504310    232  0.116
# Well-off             123707.841270    0.579365         0.539683    252  0.126

# %%
seg_res['labels'] = seg_res['Segment'].map({0:'Fewer Opportunities',1:'Standard',
                    2:'Career Focused',3:'Well-off'})

# %%
x_axis = seg_res['Age']
y_axis = seg_res['Income']

plt.figure(figsize=(12,9))
sns.scatterplot(x=x_axis,y=y_axis, hue=seg_res['labels'],
               palette=['g','r','c','m'])
plt.title('Segmentation K-means')
plt.show()

# %% [markdown]
# ***Output***
#
# 1. *Career Focused/ Well off are better segmented, but the other two groups overlap.*
# 2. *K-means did a reasonable job at segmentation however the result is far from perfect.*
#
# ## Dimensionality Reduction using PCA

# %%
pca = PCA()
pca.fit(df_seg_prep)
# Out:
# PCA()

# %%
plt.figure(figsize=(12,9))
plt.plot(range(1,8), pca.explained_variance_ratio_.cumsum(),
        marker ='o', linestyle='--')
plt.title('Explained Variance')
plt.xlabel('No of Components')
plt.ylabel('Cumulative variance explained')
plt.show()

# %%
pca = PCA(n_components=4)
pca.fit(df_seg_prep)
# Out:
# PCA(n_components=4)

# %% [markdown]
# ### Results

# %%
df_pca_comp = pd.DataFrame(data = pca.components_,
                          columns=df_seg.columns.values,
                          index=['Component 1','Component 2',
                                'Component 3', 'Component 4'])

# %%
sns.heatmap(df_pca_comp,
           vmin=-1, vmax=1,
           cmap='RdBu',
           annot=True)
plt.yticks([0,1,2,3], 
          ['Component 1','Component 2','Component 3', 'Component 4'],
          rotation =45, 
          fontsize =9)
plt.show()

# %% [markdown]
# ***Output***
#
# 1. ***Component 1*** - *Money*
# 2. ***Component 2*** - *Education*
# 3. ***Component 3*** - *Relations*
# 4. ***Component 4*** - *Housing*

# %%
scores_pca = pca.transform(df_seg_prep)

# %% [markdown]
# ## K-means clustering using PCA

# %%
wcss = []

for i in range(1,11):
    kmeans_pca = KMeans(n_clusters=i, init='k-means++', random_state=10)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.figure(figsize=(12,9))
plt.title('K-means Clustering')
plt.xlabel('Number of Clusters')
plt.ylabel('Within Cluster Sum Squared using PCA')
plt.plot(range(1,11), wcss, marker = 'o', linestyle = '--')
plt.show()

# %% [markdown]
# *From the plot above,
# To select the number of clusters for K-means clustering, we select the elbow of the graph. i.e Check where our curve smooths after a steep drop. (4 clusters)*

# %%
kmeans_pca = KMeans(n_clusters=4, init='k-means++', random_state=10)
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=10)

# %% [markdown]
# ## Results

# %%
seg_res_pca = pd.concat([df_seg.reset_index(drop=True),
                       pd.DataFrame(scores_pca)], axis=1)
seg_res_pca.columns.values[-4:] = ['Component 1','Component 2',
                                'Component 3', 'Component 4']
seg_res_pca['Segment'] = kmeans_pca.labels_

# %%
seg_res_pca.head()
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1
#
#    Component 1  Component 2  Component 3  Component 4  Segment
# 0     1.623344     1.385229    -1.124978     1.201762        3
# 1     0.789177    -1.098765     1.017516     0.573316        2
# 2    -0.861404     0.982265    -1.133028    -0.122669        0
# 3     1.331467     0.131648    -0.508426    -0.591089        1
# 4     1.113729     0.526599    -0.831148    -0.235072        1

# %%
seg_res_pca_freq = seg_res_pca.groupby(['Segment']).mean()

# %% [markdown]
# ***Segments***
#
# 0. *Fewer Opportunities*
# 1. *Well off*
# 2. *Standard*
# 3. *Career Focused*

# %%
seg_res_pca_freq['n_obs'] = seg_res_pca[['Segment','Age']].groupby(['Segment']).count()
seg_res_pca_freq['prop'] = seg_res_pca_freq['n_obs'] / seg_res_pca_freq['n_obs'].sum()

# %%
seg_res_pca_freq.rename({0:'Fewer Opportunities',2:'Standard',
                    3:'Career Focused',1:'Well-off'})
# Out:
#                           Sex  Marital status        Age  Education  \
# Segment
# Fewer Opportunities  0.596871        0.521059  30.965102   0.844765
# Well-off             0.233463        0.369650  44.758755   1.334630
# Standard             0.337368        0.475038  31.527988   0.818457
# Career Focused       0.537849        0.601594  54.752988   1.952191
#
#                             Income  Occupation  Settlement size  Component 1  \
# Segment
# Fewer Opportunities   96938.506619    0.399519         0.006017    -1.073405
# Well-off             189953.941634    1.673152         1.451362     2.124461
# Standard             123187.239032    1.078669         1.458396     0.375953
# Career Focused       123936.298805    0.581673         0.541833     0.388478
#
#                      Component 2  Component 3  Component 4  n_obs    prop
# Segment
# Fewer Opportunities     0.062942     0.028642    -0.261707    831  0.4155
# Well-off                0.025326     0.122617    -0.373228    257  0.1285
# Standard               -0.667090    -0.048012     0.389712    661  0.3305
# Career Focused          1.522443    -0.093937     0.222302    251  0.1255

# %%
seg_res_pca['labels'] = seg_res_pca['Segment'].map({0:'Fewer Opportunities',2:'Standard',
                    3:'Career Focused',1:'Well-off'})

# %%
x_axis = seg_res_pca['Component 1']
y_axis = seg_res_pca['Component 2']

plt.figure(figsize=(12,9))
sns.scatterplot(x=x_axis,y=y_axis, hue=seg_res_pca['labels'],
               palette=['g','r','c','m'])
plt.title('Segmentation K-means using PCA')
plt.show()

# %% [markdown]
# ***Output***
#
# *K-means using PCA did a better job at segmentation however not perfect.*
#
# ## Export Model

# %%
pickle.dump(scale, open('scaler.pickle','wb'))

# %%
pickle.dump(pca, open('pca.pickle','wb'))

# %%
pickle.dump(kmeans_pca, open('kmeans_pca.pickle','wb'))
